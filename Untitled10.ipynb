# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
df=pd.read_csv('/content/amazon.csv')
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# 1         ₹349                 43%    4.0       43,994
# 2       ₹1,899                 90%    3.9        7,928
# 3         ₹699                 53%    4.2       94,363
# 4         ₹399                 61%    4.2       16,905
#
#                                        about_product  \
# 0  High Compatibility : Compatible With iPhone 12...
# 1  Compatible with all Type C enabled devices, be...
# 2  【 Fast Charger& Data Sync】-With built-in safet...
# 3  The boAt Deuce USB 300 2 in 1 cable is compati...
# 4  [CHARGE & SYNC FUNCTION]- This cable comes wit...
#
#                                              user_id  \
# 0  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 1  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# 2  AGU3BBQ2V2DDAMOAKGFAWDDQ6QHA,AESFLDV2PT363T2AQ...
# 3  AEWAZDZZJLQUYVOVGBEUKSLXHQ5A,AG5HTSFRRE6NL3M5S...
# 4  AE3Q6KSUK5P75D5HFYHCRAOLODSA,AFUGIFH5ZAFXRDSZH...
#
#                                            user_name  \
# 0  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 1  ArdKn,Nirbhay kumar,Sagar Viswanathan,Asp,Plac...
# 2  Kunal,Himanshu,viswanath,sai niharka,saqib mal...
# 3  Omkar dhale,JD,HEMALATHA,Ajwadh a.,amar singh ...
# 4  rahuls6099,Swasat Borah,Ajay Wadke,Pranali,RVK...
#
#                                            review_id  \
# 0  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 1  RGIQEG07R9HS2,R1SMWZQ86XIN8U,R2J3Y1WL29GWDE,RY...
# 2  R3J3EQQ9TZI5ZJ,R3E7WBGK7ID0KV,RWU79XKQ6I1QF,R2...
# 3  R3EEUZKKK9J36I,R3HJVYCLYOY554,REDECAZ7AMPQC,R1...
# 4  R1BP4L2HH9TFUP,R16PVJEXKV6QZS,R2UPDB81N66T4P,R...
#
#                                         review_title  \
# 0  Satisfied,Charging is really fast,Value for mo...
# 1  A Good Braided Cable for Your Type C Device,Go...
# 2  Good speed for earlier versions,Good Product,W...
# 3  Good product,Good one,Nice,Really nice product...
# 4  As good as original,Decent,Good one for second...
#
#                                       review_content  \
# 0  Looks durable Charging is fine tooNo complains...
# 1  I ordered this cable to connect my phone to An...
# 2  Not quite durable and sturdy,https://m.media-a...
# 3  Good product,long wire,Charges good,Nice,I bou...
# 4  Bought this instead of original apple, does th...
#
#                                             img_link  \
# 0  https://m.media-amazon.com/images/W/WEBP_40237...
# 1  https://m.media-amazon.com/images/W/WEBP_40237...
# 2  https://m.media-amazon.com/images/W/WEBP_40237...
# 3  https://m.media-amazon.com/images/I/41V5FtEWPk...
# 4  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                         product_link
# 0  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 1  https://www.amazon.in/Ambrane-Unbreakable-Char...
# 2  https://www.amazon.in/Sounce-iPhone-Charging-C...
# 3  https://www.amazon.in/Deuce-300-Resistant-Tang...
# 4  https://www.amazon.in/Portronics-Konnect-POR-1...

# %%
df.shape
# Out:
# (1465, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   object
#  4   actual_price         1465 non-null   object
#  5   discount_percentage  1465 non-null   object
#  6   rating               1465 non-null   object
#  7   rating_count         1463 non-null   object
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
#  15  product_link         1465 non-null   object
# dtypes: object(16)
# memory usage: 183.2+ KB

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# product_id             0.000000
# product_name           0.000000
# category               0.000000
# discounted_price       0.000000
# actual_price           0.000000
# discount_percentage    0.000000
# rating                 0.000000
# rating_count           0.136519
# about_product          0.000000
# user_id                0.000000
# user_name              0.000000
# review_id              0.000000
# review_title           0.000000
# review_content         0.000000
# img_link               0.000000
# product_link           0.000000
# dtype: float64

# %%
df.drop(['product_id','user_id','user_name','review_id','img_link','product_link'], axis=1, inplace=True)
df.head()
# Out:
#                                         product_name  \
# 0  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# 1         ₹349                 43%    4.0       43,994
# 2       ₹1,899                 90%    3.9        7,928
# 3         ₹699                 53%    4.2       94,363
# 4         ₹399                 61%    4.2       16,905
#
#                                        about_product  \
# 0  High Compatibility : Compatible With iPhone 12...
# 1  Compatible with all Type C enabled devices, be...
# 2  【 Fast Charger& Data Sync】-With built-in safet...
# 3  The boAt Deuce USB 300 2 in 1 cable is compati...
# 4  [CHARGE & SYNC FUNCTION]- This cable comes wit...
#
#                                         review_title  \
# 0  Satisfied,Charging is really fast,Value for mo...
# 1  A Good Braided Cable for Your Type C Device,Go...
# 2  Good speed for earlier versions,Good Product,W...
# 3  Good product,Good one,Nice,Really nice product...
# 4  As good as original,Decent,Good one for second...
#
#                                       review_content
# 0  Looks durable Charging is fine tooNo complains...
# 1  I ordered this cable to connect my phone to An...
# 2  Not quite durable and sturdy,https://m.media-a...
# 3  Good product,long wire,Charges good,Nice,I bou...
# 4  Bought this instead of original apple, does th...

# %%
df=df.dropna()

# %%
df['actual_price'] = df['actual_price'].str.replace('₹', '').str.replace(',', '')
df['actual_price'] = df['actual_price'].astype(float)

df['discounted_price'] = df['discounted_price'].str.replace('₹', '').str.replace(',', '')
df['discounted_price'] = df['discounted_price'].astype(float)

df['discount_percentage'] = df['discount_percentage'].str.replace('%', '')
df['discount_percentage'] = df['discount_percentage'].astype(int)

df['rating_count'] = df['rating_count'].str.replace(',', '')
df['rating_count'] = df['rating_count'].astype(int)

df['rating'] = df['rating'].replace('|', np.nan)
df['rating'] = df['rating'].astype(float)

# %%
df.head()
# Out:
#                                         product_name  \
# 0  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category  discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             399.0
# 1  Computers&Accessories|Accessories&Peripherals|...             199.0
# 2  Computers&Accessories|Accessories&Peripherals|...             199.0
# 3  Computers&Accessories|Accessories&Peripherals|...             329.0
# 4  Computers&Accessories|Accessories&Peripherals|...             154.0
#
#    actual_price  discount_percentage  rating  rating_count  \
# 0        1099.0                   64     4.2         24269
# 1         349.0                   43     4.0         43994
# 2        1899.0                   90     3.9          7928
# 3         699.0                   53     4.2         94363
# 4         399.0                   61     4.2         16905
#
#                                        about_product  \
# 0  High Compatibility : Compatible With iPhone 12...
# 1  Compatible with all Type C enabled devices, be...
# 2  【 Fast Charger& Data Sync】-With built-in safet...
# 3  The boAt Deuce USB 300 2 in 1 cable is compati...
# 4  [CHARGE & SYNC FUNCTION]- This cable comes wit...
#
#                                         review_title  \
# 0  Satisfied,Charging is really fast,Value for mo...
# 1  A Good Braided Cable for Your Type C Device,Go...
# 2  Good speed for earlier versions,Good Product,W...
# 3  Good product,Good one,Nice,Really nice product...
# 4  As good as original,Decent,Good one for second...
#
#                                       review_content
# 0  Looks durable Charging is fine tooNo complains...
# 1  I ordered this cable to connect my phone to An...
# 2  Not quite durable and sturdy,https://m.media-a...
# 3  Good product,long wire,Charges good,Nice,I bou...
# 4  Bought this instead of original apple, does th...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1463 entries, 0 to 1464
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_name         1463 non-null   object
#  1   category             1463 non-null   object
#  2   discounted_price     1463 non-null   float64
#  3   actual_price         1463 non-null   float64
#  4   discount_percentage  1463 non-null   int64
#  5   rating               1462 non-null   float64
#  6   rating_count         1463 non-null   int64
#  7   about_product        1463 non-null   object
#  8   review_title         1463 non-null   object
#  9   review_content       1463 non-null   object
# dtypes: float64(3), int64(2), object(5)
# memory usage: 125.7+ KB

# %%
df_cat = df['category'].str.split('|', expand=True).rename(columns={0:'category_1', 1:'category_2', 2:'category_3', 3:'category_4',4:'category_5'})

df['category_1'] = df_cat['category_1']
df['category_2'] = df_cat['category_2']
df['category_3'] = df_cat['category_3']
df['category_4'] = df_cat['category_4']

df.drop('category', axis=1, inplace=True)
df.head()
# Out:
#                                         product_name  discounted_price  \
# 0  Wayona Nylon Braided USB to Lightning Fast Cha...             399.0
# 1  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...             199.0
# 2  Sounce Fast Phone Charging Cable & Data Sync U...             199.0
# 3  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...             329.0
# 4  Portronics Konnect L 1.2M Fast Charging 3A 8 P...             154.0
#
#    actual_price  discount_percentage  rating  rating_count  \
# 0        1099.0                   64     4.2         24269
# 1         349.0                   43     4.0         43994
# 2        1899.0                   90     3.9          7928
# 3         699.0                   53     4.2         94363
# 4         399.0                   61     4.2         16905
#
#                                        about_product  \
# 0  High Compatibility : Compatible With iPhone 12...
# 1  Compatible with all Type C enabled devices, be...
# 2  【 Fast Charger& Data Sync】-With built-in safet...
# 3  The boAt Deuce USB 300 2 in 1 cable is compati...
# 4  [CHARGE & SYNC FUNCTION]- This cable comes wit...
#
#                                         review_title  \
# 0  Satisfied,Charging is really fast,Value for mo...
# 1  A Good Braided Cable for Your Type C Device,Go...
# 2  Good speed for earlier versions,Good Product,W...
# 3  Good product,Good one,Nice,Really nice product...
# 4  As good as original,Decent,Good one for second...
#
#                                       review_content             category_1  \
# 0  Looks durable Charging is fine tooNo complains...  Computers&Accessories
# 1  I ordered this cable to connect my phone to An...  Computers&Accessories
# 2  Not quite durable and sturdy,https://m.media-a...  Computers&Accessories
# 3  Good product,long wire,Charges good,Nice,I bou...  Computers&Accessories
# 4  Bought this instead of original apple, does th...  Computers&Accessories
#
#                 category_2          category_3 category_4
# 0  Accessories&Peripherals  Cables&Accessories     Cables
# 1  Accessories&Peripherals  Cables&Accessories     Cables
# 2  Accessories&Peripherals  Cables&Accessories     Cables
# 3  Accessories&Peripherals  Cables&Accessories     Cables
# 4  Accessories&Peripherals  Cables&Accessories     Cables

# %%
df.sample(50)
# Out:
#                                            product_name  discounted_price  \
# 91    OnePlus 108 cm (43 inches) Y Series Full HD Sm...           24999.0
# 156   Belkin Apple Certified Lightning To Type C Cab...            1499.0
# 1324  iBELL SM1515NEW Sandwich Maker with Floating H...            1474.0
# 497   iQOO Z6 Pro 5G by vivo (Phantom Dusk, 8GB RAM,...           20999.0
# 1422  Monitor AC Stand/Heavy Duty Air Conditioner Ou...             699.0
# 1365  Kitchen Kit Electric Kettle, 1.8L Stainless St...             479.0
# 878                     Parker Quink Ink Bottle (Black)              90.0
# 1050  R B Nova Lint/Fabric Shaver for Cloths, Lint R...             398.0
# 584   boAt BassHeads 100 in-Ear Wired Headphones wit...             365.0
# 724   Logitech B100 Wired USB Mouse, 3 yr Warranty, ...             279.0
# 1048  Lifelong LLEK15 Electric Kettle 1.5L with Stai...             549.0
# 827   Fire-Boltt Ninja Calling 1.69" Bluetooth Calli...            1999.0
# 92    boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...             299.0
# 684   AmazonBasics Flexible Premium HDMI Cable (Blac...             219.0
# 1103   Bajaj Waterproof 1500 Watts Immersion Rod Heater             653.0
# 1301  Livpure Glo Star RO+UV+UF+Mineraliser - 7 L St...            8499.0
# 237   Wayona 3in1 Nylon Braided 66W USB Fast Chargin...             449.0
# 1291  Crompton Insta Delight Fan Circulator Room Hea...            2590.0
# 1011           HP v222w 64GB USB 2.0 Pen Drive (Silver)             449.0
# 1098  Eureka Forbes Trendy Zip 1000 Watts powerful s...            2799.0
# 1296  Shakti Technology S5 High Pressure Car Washer ...            5999.0
# 464   MI Braided USB Type-C Cable for Charging Adapt...             349.0
# 307   ZORBES® Wall Adapter Holder for Alexa Echo Dot...             893.0
# 51    Using it with my QC 3 Charger .So far- So good...
# 1454  Okay,Use full only kid's clothes,Good for begi...
#
#                                          review_content  \
# 91    This OnePlus TV is great if you want a afforda...
# 156   Good cable. got original product and it is dur...
# 1324  The product is working fine. But at this price...
# 497   The camera is good, phone is quite respponsive...
# 1422  Nice product fit to the purpose,Stand is sturd...
# 1365  Thik hai,Recommend for you,Riturn my product i...
# 878   I USE PARKER INK FOR CALLIGRAPHY AND IT IS WOR...
# 1050  I've been an Amazon customer since 2014/15. Th...
# 584   The sound quality of this earphone are really ...
# 724   Liked this Product,https://m.media-amazon.com/...
# 1048  Well over all iits nice, make sure the lid of ...
# 827   I've been using the watch for a while now and ...
# 92    Good product,long wire,Charges good,Nice,I bou...
# 684   I am using it for 14 days now. The experience ...
# 1103  इस Road Heater से एक बाल्टी पानी गर्म करने में...
# 1301  ,Good product.Initially a duplicate product wa...
# 237   Affordable, available and multi purpose cable ...
# 1291  no,There should be a fan speed control option....
# 1011  https://m.media-amazon.com/images/I/71mathm1ap...
# 1098  Its not a very great procut if u r looking for...
# 1296  Product works very well, easy to use i recomme...
# 464   I like it 👍👍,Best charging power . I used this...
# 307   ,If you have brain,its very easy to install an...
# 1063  I am writting this after 4months usuage ,Go fo...
# 250   The remote is so far good and works smoothly w...
# 809   Working as described but too early to comment ...
# 727   Worked on iPhone 7 and didn’t work on iPhone X...
# 185   Price is high in respect of product quality,Du...
# 1152  This product little bit costly but quality was...
# 1393  The only issue is that the built quality is ve...
# 593   128GB SD Card is showing 134GBDon't buy this p...
# 1207  Does the work,Good,Superb,All good.,Philips a ...
# 383   After using the phone for a day, I feel corner...
# 946   Product is good and better🙂Not bad,Value for m...
# 916   Stopped working after a month of use. Don't wa...
# 446   I like it,Great phone in smaller amount these ...
# 425   I am not big on camera usage, personally. I wa...
# 25    The signal is too unstable once connect you ne...
# 395   ,Wow!!! Just wow!!! How can a beautiful produc...
# 147   The cable does support fast PD charging, I hav...
# 556   Expect it will last long, price wise it's a go...
# 1221  First of all i wanted to buy one juicer to hav...
# 477   ,Overall meets the requirements nothing to say...
# 407   Very nice product and easy to use as well as v...
# 1255  A great product of convenience. The only drawb...
# 155   tv on off not working, so difficult to battery...
# 1182  Lights inbuilt in this create psychological ef...
# 1065  Recieved the package today . The product came ...
# 51    ABOUT  AMAZONBASICS:xxxxxxxxxxxxxxxxxxxxxxxxxx...
# 1454  Overall I liked the productBut disappointed wi...
#
#                  category_1                      category_2  \
# 91              Electronics            HomeTheater,TV&Video
# 156   Computers&Accessories         Accessories&Peripherals
# 1324           Home&Kitchen          Kitchen&HomeAppliances
# 497             Electronics             Mobiles&Accessories
# 1422           Home&Kitchen      Heating,Cooling&AirQuality
# 1365           Home&Kitchen          Kitchen&HomeAppliances
# 878          OfficeProducts             OfficePaperProducts
# 1050           Home&Kitchen          Kitchen&HomeAppliances
# 584             Electronics  Headphones,Earbuds&Accessories
# 724   Computers&Accessories         Accessories&Peripherals
# 464            Cables&Accessories                                Cables
# 307                   Accessories            TVMounts,Stands&Turntables
# 1063      Vacuum,Cleaning&Ironing                     Vacuums&FloorCare
# 250                   Accessories                        RemoteControls
# 809                       Routers                                  None
# 727            Cables&Accessories                                Cables
# 185            Cables&Accessories                                Cables
# 1152      Vacuum,Cleaning&Ironing            Irons,Steamers&Accessories
# 1393      Vacuum,Cleaning&Ironing            Irons,Steamers&Accessories
# 593                   MemoryCards                               MicroSD
# 1207      Vacuum,Cleaning&Ironing            Irons,Steamers&Accessories
# 383      Smartphones&BasicMobiles                           Smartphones
# 946             LaptopAccessories                          Bags&Sleeves
# 916                    Headphones                              Over-Ear
# 446      Smartphones&BasicMobiles                           Smartphones
# 425      Smartphones&BasicMobiles                           Smartphones
# 25                    Accessories                                Cables
# 395                  SmartWatches                                  None
# 147            Cables&Accessories                                Cables
# 556             MobileAccessories                              Chargers
# 1221       SmallKitchenAppliances                               Juicers
# 477      Smartphones&BasicMobiles                           Smartphones
# 407            Cables&Accessories             CableConnectionProtectors
# 1255       SmallKitchenAppliances                        SandwichMakers
# 155                   Accessories                        RemoteControls
# 1182                 AirPurifiers                      HEPAAirPurifiers
# 1065       SmallKitchenAppliances                      InductionCooktop
# 51             Cables&Accessories                                Cables
# 1454   SewingMachines&Accessories             Sewing&EmbroideryMachines

# %%
df.isnull().sum()
# Out:
# product_name             0
# discounted_price         0
# actual_price             0
# discount_percentage      0
# rating                   1
# rating_count             0
# about_product            0
# review_title             0
# review_content           0
# category_1               0
# category_2               0
# category_3               8
# category_4             165
# dtype: int64

# %%
df=df.dropna()

# %%
df['Price']=df['discounted_price']*df['rating_count']
df['Price']
# Out:
# 0        9683331.0
# 1        8754806.0
# 2        1577672.0
# 3       31045427.0
# 4        2603370.0
#            ...
# 1460      413110.0
# 1461     9389040.0
# 1462     1038492.0
# 1463    11235369.0
# 1464    20003781.0
# Name: Price, Length: 1297, dtype: float64

# %%
result1 = df.groupby('category_3')['rating'].agg(['mean', 'min', 'max'])
result1['mean'] = result1['mean'].round(2)
result1
# Out:
#                              mean  min  max
# category_3
# Accessories                  4.00  3.0  4.6
# Adapters                     4.15  4.0  4.3
# AirConditioners              4.30  4.3  4.3
# AirPurifiers                 4.28  4.1  4.4
# Audio&VideoAccessories       3.89  3.3  4.3
# Cables&Accessories           4.15  3.3  5.0
# Calculators                  4.45  4.4  4.5
# Coffee,Tea&Espresso          4.01  3.3  4.5
# Drawing&PaintingSupplies     4.30  4.3  4.3
# DrawingMaterials             4.35  4.3  4.4
# Fans                         4.09  3.8  4.3
# Flashes                      3.80  3.8  3.8
# HardDriveAccessories         4.10  4.1  4.1
# Headphones                   3.92  3.4  4.2
# HealthMonitors               4.00  4.0  4.0
# Inks,Toners&Cartridges       4.23  4.0  4.4
# InteriorAccessories          3.80  3.8  3.8
# Keyboards,Mice&InputDevices  4.16  3.3  5.0
# KitchenTools                 4.10  4.1  4.1
# LaptopAccessories            4.13  3.5  4.5
# LaundryOrganization          4.03  3.7  4.3
# MediaStreamingDevices        4.50  4.5  4.5
# MemoryCards                  4.34  4.0  4.5
# MobileAccessories            4.17  3.6  4.7
# NetworkAdapters              4.12  3.4  4.5
# PCGamingPeripherals          4.29  3.8  4.6
# PaintingMaterials            4.43  4.4  4.5
# Paper                        4.29  4.0  4.5
# Parts&Accessories            4.10  4.1  4.1
# Printers                     3.60  3.4  3.8
# RoomHeaters                  3.83  2.0  4.6
# SatelliteEquipment           4.27  4.2  4.3
# Scrapbooking                 3.90  3.9  3.9
# SecurityCameras              4.10  3.8  4.3
# SewingMachines&Accessories   3.65  3.1  4.3
# SmallKitchenAppliances       4.05  2.3  4.8
# Smartphones&BasicMobiles     4.08  3.5  4.4
# Speakers                     4.02  3.7  4.3
# TabletAccessories            4.20  4.0  4.5
# Televisions                  4.20  3.4  4.7
# USBGadgets                   3.94  3.6  4.3
# Vacuum,Cleaning&Ironing      4.08  3.1  4.6
# WaterHeaters&Geysers         4.08  3.4  4.8
# WaterPurifiers&Accessories   4.05  2.9  4.6

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Plotting line plot for min and max ratings
result1[['min', 'mean','max']].plot(kind='line', marker='o')

# Set titles and labels
plt.title('Ratings Summary by Product Category')
plt.xlabel('Product Category')
plt.ylabel('Avg, min, max rating')
plt.legend()
plt.xticks(rotation=45)
# Show the plots
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'result' DataFrame contains the aggregated data

# Plotting a single bar chart for mean, min, and max ratings
result1.plot(kind='bar', color=['skyblue', 'lightgreen', 'salmon'])

# Set titles and labels
plt.title('Ratings Summary by Product Category')
plt.xlabel('Product Category')
plt.ylabel('Rating')
plt.legend(['Mean Rating', 'Min Rating', 'Max Rating'])

# Show the plot
plt.show()

# %%
result1 = df.groupby('category_3')['discount_percentage'].agg(['mean', 'min', 'max'])
result1['mean'] = result1['mean'].round(2)
result1
# Out:
#                               mean  min  max
# category_3
# Accessories                  56.93    0   88
# Adapters                     78.50   63   94
# AirConditioners              43.00   43   43
# AirPurifiers                 41.00   23   76
# Audio&VideoAccessories       47.14   23   66
# Cables&Accessories           59.57    0   90
# Calculators                   1.25    0    5
# Coffee,Tea&Espresso          41.93   17   60
# Drawing&PaintingSupplies      0.00    0    0
# DrawingMaterials              5.00    0   10
# Fans                         36.35   15   58
# Flashes                      60.00   60   60
# HardDriveAccessories         75.00   75   75
# Headphones                   57.85    0   85
# HealthMonitors               53.00   53   53
# Inks,Toners&Cartridges       28.83    4   73
# InteriorAccessories          42.00   42   42
# Keyboards,Mice&InputDevices  47.32    8   88
# KitchenTools                 60.00   60   60
# LaptopAccessories            57.42    0   85
# LaundryOrganization          46.06   11   68
# MediaStreamingDevices         0.00    0    0
# MemoryCards                  57.79   43   77
# MobileAccessories            60.99    7   90
# NetworkAdapters              47.85   17   78
# PCGamingPeripherals          43.00   14   79
# PaintingMaterials             9.33    0   15
# Paper                        14.00    0   75
# Parts&Accessories            59.00   59   59
# Printers                     11.50   10   13
# RoomHeaters                  38.23    4   67
# SatelliteEquipment           51.33   46   60
# Scrapbooking                 21.00   21   21
# SecurityCameras              42.60   24   69
# SewingMachines&Accessories   40.50   19   52
# SmallKitchenAppliances       41.19    0   90
# Smartphones&BasicMobiles     22.74    0   49
# Speakers                     50.54   25   70
# TabletAccessories            66.25   23   78
# Televisions                  39.49    0   65
# USBGadgets                   16.00    0   70
# Vacuum,Cleaning&Ironing      39.14    3   80
# WaterHeaters&Geysers         43.91    7   71
# WaterPurifiers&Accessories   37.23    0   86

# %%
result1.reset_index(inplace=True)

# Plotting a bar chart using Seaborn
plt.figure(figsize=(10, 6))
sns.barplot(x='category_3', y='mean', data=result1, color='skyblue', label='Mean')
sns.barplot(x='category_3', y='max', data=result1, color='salmon', alpha=0.7, label='Max')
sns.barplot(x='category_3', y='min', data=result1, color='lightgreen', alpha=0.6, label='Min')

# Set titles and labels
plt.title('Discount Percentage Summary by Category')
plt.xlabel('Category')
plt.ylabel('Discount Percentage')
plt.legend()

# Show the plot
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
df.head()
# Out:
#                                         product_name  discounted_price  \
# 0  Wayona Nylon Braided USB to Lightning Fast Cha...             399.0
# 1  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...             199.0
# 2  Sounce Fast Phone Charging Cable & Data Sync U...             199.0
# 3  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...             329.0
# 4  Portronics Konnect L 1.2M Fast Charging 3A 8 P...             154.0
#
#    actual_price  discount_percentage  rating  rating_count  \
# 0        1099.0                   64     4.2         24269
# 1         349.0                   43     4.0         43994
# 2        1899.0                   90     3.9          7928
# 3         699.0                   53     4.2         94363
# 4         399.0                   61     4.2         16905
#
#                                        about_product  \
# 0  High Compatibility : Compatible With iPhone 12...
# 1  Compatible with all Type C enabled devices, be...
# 2  【 Fast Charger& Data Sync】-With built-in safet...
# 3  The boAt Deuce USB 300 2 in 1 cable is compati...
# 4  [CHARGE & SYNC FUNCTION]- This cable comes wit...
#
#                                         review_title  \
# 0  Satisfied,Charging is really fast,Value for mo...
# 1  A Good Braided Cable for Your Type C Device,Go...
# 2  Good speed for earlier versions,Good Product,W...
# 3  Good product,Good one,Nice,Really nice product...
# 4  As good as original,Decent,Good one for second...
#
#                                       review_content             category_1  \
# 0  Looks durable Charging is fine tooNo complains...  Computers&Accessories
# 1  I ordered this cable to connect my phone to An...  Computers&Accessories
# 2  Not quite durable and sturdy,https://m.media-a...  Computers&Accessories
# 3  Good product,long wire,Charges good,Nice,I bou...  Computers&Accessories
# 4  Bought this instead of original apple, does th...  Computers&Accessories
#
#                 category_2          category_3 category_4       Price
# 0  Accessories&Peripherals  Cables&Accessories     Cables   9683331.0
# 1  Accessories&Peripherals  Cables&Accessories     Cables   8754806.0
# 2  Accessories&Peripherals  Cables&Accessories     Cables   1577672.0
# 3  Accessories&Peripherals  Cables&Accessories     Cables  31045427.0
# 4  Accessories&Peripherals  Cables&Accessories     Cables   2603370.0

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='category_3', data=df, palette='viridis')
plt.title('Distribution of Categories')
plt.xlabel('Category')
plt.ylabel('Count')

plt.xticks(rotation=90)

plt.tight_layout()
plt.show()

# %%
x=df[['category_3','rating_count']]
xx = x.sort_values(by='rating_count', ascending=False)
xx.reset_index(inplace=True,drop=True)
xx.head(20)
# Out:
#                   category_3  rating_count
# 0                Accessories        426973
# 1                Accessories        426973
# 2                Accessories        426973
# 3                Accessories        426972
# 4                 Headphones        363713
# 5                 Headphones        363713
# 6                 Headphones        363711
# 7   Smartphones&BasicMobiles        313836
# 8   Smartphones&BasicMobiles        313836
# 9   Smartphones&BasicMobiles        313832
# 10  Smartphones&BasicMobiles        313832
# 11                Headphones        273189
# 12              KitchenTools        270563
# 13               MemoryCards        205052
# 14                Headphones        192590
# 15                Headphones        192589
# 16                Headphones        192587
# 17                Headphones        180998
# 18           NetworkAdapters        179692
# 19           NetworkAdapters        179691

# %%
data1=xx.loc[0:19]
plt.figure(figsize=(10, 6))
sns.barplot(x='rating_count', y='category_3', data=data1, palette='viridis',orient='h')

plt.title('Top 20 Ratings by Category')
plt.xlabel('Category')
plt.ylabel('Rating Count')

plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
x=df[['category_3','rating']]
xx = x.sort_values(by='rating', ascending=False)
xx.reset_index(inplace=True,drop=True)
xx.head(20)
# Out:
#                      category_3  rating
# 0            Cables&Accessories     5.0
# 1   Keyboards,Mice&InputDevices     5.0
# 2        SmallKitchenAppliances     4.8
# 3          WaterHeaters&Geysers     4.8
# 4        SmallKitchenAppliances     4.8
# 5          WaterHeaters&Geysers     4.7
# 6        SmallKitchenAppliances     4.7
# 7                   Televisions     4.7
# 8        SmallKitchenAppliances     4.7
# 9             MobileAccessories     4.7
# 10       SmallKitchenAppliances     4.7
# 11  Keyboards,Mice&InputDevices     4.6
# 12                  Accessories     4.6
# 13      Vacuum,Cleaning&Ironing     4.6
# 14                  RoomHeaters     4.6
# 15   WaterPurifiers&Accessories     4.6
# 16          PCGamingPeripherals     4.6
# 17  Keyboards,Mice&InputDevices     4.6
# 18          PCGamingPeripherals     4.6
# 19            MobileAccessories     4.6

# %%
data2=xx.loc[0:20]



plt.figure(figsize=(10, 6))
sns.barplot(x='rating', y='category_3', data=data2, palette='viridis',orient='h')

plt.title('Top 20 Ratings by Category')
plt.xlabel('Category')
plt.ylabel('Rating')

plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
result1.reset_index(inplace=True)

# Plotting a bar chart using Seaborn
plt.figure(figsize=(10, 6))
sns.barplot(x='category_3', y='mean', data=result1, color='skyblue')


# Set titles and labels
plt.title('Total Sell Each Category')
plt.xlabel('Category')
plt.ylabel('Total Sell')
plt.legend()

# Show the plot
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
result1 = df.groupby('category_3')['Price'].agg(['mean', 'min'])
result1['mean'] = result1['mean'].round(2)
result1
# Out:
#                                      mean          min
# category_3
# Accessories                  7.353092e+06       4625.0
# Adapters                     7.653520e+05     229460.0
# AirConditioners              1.389007e+08  138900690.0
# AirPurifiers                 4.039344e+07   29374974.0
# Audio&VideoAccessories       1.291439e+07     557996.0
# Cables&Accessories           4.999563e+06       1995.0
# Calculators                  4.993237e+06    2367910.0
# Coffee,Tea&Espresso          2.013796e+06      42365.0
# Drawing&PaintingSupplies     2.380050e+06    2380050.0
# DrawingMaterials             7.315920e+05     498564.0
# Fans                         1.764632e+07     952403.0
# Flashes                      1.035344e+07   10353442.0
# HardDriveAccessories         1.459267e+06    1459267.0
# Headphones                   6.146239e+07      82194.0
# HealthMonitors               3.293037e+06    3293037.0
# Inks,Toners&Cartridges       2.631637e+06     750483.0
# InteriorAccessories          2.615002e+06    2615002.0
# Keyboards,Mice&InputDevices  1.026938e+07       3675.0
# KitchenTools                 5.384204e+07   53842037.0
# LaptopAccessories            5.572347e+06      17595.0
# LaundryOrganization          1.417203e+06      18020.0
# MediaStreamingDevices        1.052576e+06    1052576.0
# MemoryCards                  7.216567e+07   12038625.0
# MobileAccessories            1.627802e+07       3066.0
# NetworkAdapters              3.115263e+07      35534.0
# PCGamingPeripherals          1.117325e+07     619752.0
# PaintingMaterials            1.744398e+06    1375773.0
# Paper                        9.560660e+05      38412.0
# Parts&Accessories            2.463276e+06    2463276.0
# Printers                     3.655684e+07   30490548.0
# RoomHeaters                  2.425402e+06       2598.0
# SatelliteEquipment           4.318154e+06     390999.0
# Scrapbooking                 1.921140e+06    1921140.0
# SecurityCameras              9.185598e+07    3758120.0
# SewingMachines&Accessories   3.419101e+07    1583428.0
# SmallKitchenAppliances       1.452118e+07       1673.0
# Smartphones&BasicMobiles     3.909591e+08     999750.0
# Speakers                     2.792768e+07     333982.0
# TabletAccessories            4.734935e+06     253930.0
# Televisions                  2.537159e+08     767360.0
# USBGadgets                   2.990382e+05      21449.0
# Vacuum,Cleaning&Ironing      1.336723e+07        398.0
# WaterHeaters&Geysers         1.907866e+07      27512.0
# WaterPurifiers&Accessories   2.781200e+07       7141.0

# %%
result1.reset_index(inplace=True)

result_melted = result1.melt(id_vars='category_3', var_name='Stat', value_name='Price')

plt.figure(figsize=(10, 6))
sns.lineplot(x='category_3', y='Price', hue='Stat', data=result_melted, marker='o')

plt.title('Price Summary by Category')
plt.xlabel('Category')
plt.ylabel('Total Sell')
plt.legend(title='Statistic')

plt.xticks(rotation=90)

plt.tight_layout()
plt.show()

# %%
# Plotting a bar chart using Seaborn
plt.figure(figsize=(10, 6))
sns.barplot(x='category_3', y='actual_price', data=df, color='skyblue', label='Actual_Price')
sns.barplot(x='category_3', y='discounted_price', data=df, color='salmon', alpha=0.7, label='Discount_Price')


# Set titles and labels
plt.title('Actual Price Vs Discount Price')
plt.xlabel('Category')
plt.ylabel('Prices')
plt.legend()

# Show the plot
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# Linear regression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/amazon.csv")
df
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1     Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2     Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3     Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4     Computers&Accessories|Accessories&Peripherals|...             ₹154
# ...                                                 ...              ...
# 1460  Home&Kitchen|Kitchen&HomeAppliances|WaterPurif...             ₹379
# 1461  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...           ₹2,280
# 1462  Home&Kitchen|Heating,Cooling&AirQuality|RoomHe...           ₹2,219
# 1463  Home&Kitchen|Heating,Cooling&AirQuality|Fans|E...           ₹1,399
# 1464  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...           ₹2,863
#
#      actual_price discount_percentage rating rating_count  \
# 0          ₹1,099                 64%    4.2       24,269
# 1            ₹349                 43%    4.0       43,994
# 2          ₹1,899                 90%    3.9        7,928
# 3            ₹699                 53%    4.2       94,363
# 4            ₹399                 61%    4.2       16,905
# ...           ...                 ...    ...          ...
# 1460         ₹919                 59%      4        1,090
# 1461       ₹3,045                 25%    4.1        4,118
# 1462       ₹3,080                 28%    3.6          468
# 1463       ₹1,890                 26%      4        8,031
# 1464       ₹3,690                 22%    4.3        6,987
#
#                                           about_product  \
# 0     High Compatibility : Compatible With iPhone 12...
# 1     Compatible with all Type C enabled devices, be...
# 2     【 Fast Charger& Data Sync】-With built-in safet...
# 3     The boAt Deuce USB 300 2 in 1 cable is compati...
# 4     [CHARGE & SYNC FUNCTION]- This cable comes wit...
# ...                                                 ...
# 1460  SUPREME QUALITY 90 GRAM 3 LAYER THIK PP SPUN F...
# 1461                       230 Volts, 400 watts, 1 Year
# 1462  International design and styling|Two heat sett...
# 1463  Fan sweep area: 230 MM ; Noise level: (40 - 45...
# 1464  Brand-Borosil, Specification â€“ 23V ~ 5Hz;1 W...
#
#                                                 user_id  \
# 0     AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 1     AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# 2     AGU3BBQ2V2DDAMOAKGFAWDDQ6QHA,AESFLDV2PT363T2AQ...
# 3     AEWAZDZZJLQUYVOVGBEUKSLXHQ5A,AG5HTSFRRE6NL3M5S...
# 4     AE3Q6KSUK5P75D5HFYHCRAOLODSA,AFUGIFH5ZAFXRDSZH...
# ...                                                 ...
# 1460  AHITFY6AHALOFOHOZEOC6XBP4FEA,AFRABBODZJZQB6Z4U...
# 1461  AFG5FM3NEMOL6BNFRV2NK5FNJCHQ,AGEINTRN6Z563RMLH...
# 1462  AGVPWCMAHYQWJOQKMUJN4DW3KM5Q,AF4Q3E66MY4SR7YQZ...
# 1463  AF2JQCLSCY3QJATWUNNHUSVUPNQQ,AFDMLUXC5LS5RXDJS...
# 1464  AFGW5PT3R6ZAVQR4Y5MWVAKBZAYA,AG7QNJ2SCS5VS5VYY...
#
#                                               user_name  \
# 0     Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 1     ArdKn,Nirbhay kumar,Sagar Viswanathan,Asp,Plac...
# 2     Kunal,Himanshu,viswanath,sai niharka,saqib mal...
# 3     Omkar dhale,JD,HEMALATHA,Ajwadh a.,amar singh ...
# 4     rahuls6099,Swasat Borah,Ajay Wadke,Pranali,RVK...
# ...                                                 ...
# 1460  Prabha ds,Raghuram bk,Real Deal,Amazon Custome...
# 1461  Manu Bhai,Naveenpittu,Evatira Sangma,JAGANNADH...
# 1462  Nehal Desai,Danish Parwez,Amazon Customer,Amaz...
# 1463  Shubham Dubey,E.GURUBARAN,Mayank S.,eusuf khan...
# 1464  Rajib,Ajay B,Vikas Kahol,PARDEEP,Anindya Prama...
#
#                                               review_id  \
# 0     R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 1     RGIQEG07R9HS2,R1SMWZQ86XIN8U,R2J3Y1WL29GWDE,RY...
# 2     R3J3EQQ9TZI5ZJ,R3E7WBGK7ID0KV,RWU79XKQ6I1QF,R2...
# 3     R3EEUZKKK9J36I,R3HJVYCLYOY554,REDECAZ7AMPQC,R1...
# 4     R1BP4L2HH9TFUP,R16PVJEXKV6QZS,R2UPDB81N66T4P,R...
# ...                                                 ...
# 1460  R3G3XFHPBFF0E8,R3C0BZCD32EIGW,R2EBVBCN9QPD9R,R...
# 1461  R3DDL2UPKQ2CK9,R2SYYU1OATVIU5,R1VM993161IYRW,R...
# 1462  R1TLRJVW4STY5I,R2O455KRN493R1,R3Q5MVGBRIAS2G,R...
# 1463  R39Q2Y79MM9SWK,R3079BG1NIH6MB,R29A31ZELTZNJM,R...
# 1464  R20RBRZ0WEUJT9,ROKIFK9R2ISSE,R30EEG2FNJSN5I,R2...
#
#                                            review_title  \
# 0     Satisfied,Charging is really fast,Value for mo...
# 1     A Good Braided Cable for Your Type C Device,Go...
# 2     Good speed for earlier versions,Good Product,W...
# 3     Good product,Good one,Nice,Really nice product...
# 4     As good as original,Decent,Good one for second...
# ...                                                 ...
# 1460  Received the product without spanner,Excellent...
# 1461  ok,everything was good couldn't return bcoz I ...
# 1462  very good,Work but front melt after 2 month,Go...
# 1463  Fan Speed is slow,Good quality,Good product,go...
# 1464  Works perfect,Ok good product,Nice Product. Re...
#
#                                          review_content  \
# 0     Looks durable Charging is fine tooNo complains...
# 1     I ordered this cable to connect my phone to An...
# 2     Not quite durable and sturdy,https://m.media-a...
# 3     Good product,long wire,Charges good,Nice,I bou...
# 4     Bought this instead of original apple, does th...
# ...                                                 ...
# 1460  I received product without spanner,Excellent p...
# 1461  ok,got everything as mentioned but the measuri...
# 1462  plastic but cool body ,u have to find sturdy s...
# 1463  I have installed this in my kitchen working fi...
# 1464  It does it job perfectly..only issue is temp c...
#
#                                                img_link  \
# 0     https://m.media-amazon.com/images/W/WEBP_40237...
# 1     https://m.media-amazon.com/images/W/WEBP_40237...
# 2     https://m.media-amazon.com/images/W/WEBP_40237...
# 3     https://m.media-amazon.com/images/I/41V5FtEWPk...
# 4     https://m.media-amazon.com/images/W/WEBP_40237...
# ...                                                 ...
# 1460  https://m.media-amazon.com/images/I/41fDdRtjfx...
# 1461  https://m.media-amazon.com/images/I/41gzDxk4+k...
# 1462  https://m.media-amazon.com/images/W/WEBP_40237...
# 1463  https://m.media-amazon.com/images/W/WEBP_40237...
# 1464  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                            product_link
# 0     https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 1     https://www.amazon.in/Ambrane-Unbreakable-Char...
# 2     https://www.amazon.in/Sounce-iPhone-Charging-C...
# 3     https://www.amazon.in/Deuce-300-Resistant-Tang...
# 4     https://www.amazon.in/Portronics-Konnect-POR-1...
# ...                                                 ...
# 1460  https://www.amazon.in/Noir-Aqua-Spanner-Purifi...
# 1461  https://www.amazon.in/Prestige-Delight-PRWO-1-...
# 1462  https://www.amazon.in/Bajaj-RX-10-2000-Watt-Co...
# 1463  https://www.amazon.in/Havells-Ventilair-230mm-...
# 1464  https://www.amazon.in/Borosil-Jumbo-1000-Watt-...
#
# [1465 rows x 16 columns]

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   object
#  4   actual_price         1465 non-null   object
#  5   discount_percentage  1465 non-null   object
#  6   rating               1465 non-null   object
#  7   rating_count         1463 non-null   object
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
#  15  product_link         1465 non-null   object
# dtypes: object(16)
# memory usage: 183.2+ KB

# %%
df.isnull().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           2
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %%
# Convert 'rating counts' to numeric after removing  ',' symbols
df['rating_count']=df['rating_count'].replace('[\,]','',regex=True).astype(float)

# %%
#rating count missing value fill by mean
df['rating_count'].fillna(df['rating_count'].mean(), inplace=True)

# %%
# Convert 'actual price' to numeric after removing '₹' and ',' symbols
df['actual_price']=df['actual_price'].replace('[\₹,]','',regex=True).astype(float)

# %%
# Convert 'discount price' to numeric after removing '₹' and ',' symbols
df['discounted_price']=df['discounted_price'].replace('[\₹,]','',regex=True).astype(float)

# %%
# Convert 'discount_percentage' to numeric
df['discount_percentage'] = df['discount_percentage'].str.rstrip('%').astype(float)

# %%
df['rating'] = pd.to_numeric(df['rating'], errors='coerce')
#int(df1)

# %%
df['rating'].fillna(df['rating'].mean(), inplace=True)

# %%
df['rating']==1
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1460    False
# 1461    False
# 1462    False
# 1463    False
# 1464    False
# Name: rating, Length: 1465, dtype: bool

# %%
df.isnull().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           0
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %%
df['rating'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1465 entries, 0 to 1464
# Series name: rating
# Non-Null Count  Dtype
# --------------  -----
# 1465 non-null   float64
# dtypes: float64(1)
# memory usage: 11.6 KB

# %%
from sklearn.preprocessing import OneHotEncoder,LabelEncoder

# %%
label_encoder=LabelEncoder()
label_encoderd=label_encoder.fit_transform(df['category'])
label_encoderd
# Out:
# array([ 10,  10,  10, ..., 138, 129, 174])

# %%
df['encoderd_category'] = label_encoderd.tolist()

# %%
#linear regression
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
X=df[['actual_price','discounted_price','rating_count','encoderd_category']]
y=df['rating']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y
#        4.12040733, 4.04355442, 4.13440352, 4.02054102, 4.11375444,
#        4.03171015, 4.15668186, 4.0154376 , 4.12419937, 4.09480009,
#        4.08764106, 4.12011529, 4.02259092, 4.20287573, 4.06673805,
#        4.02812011, 4.02176917, 4.06358029, 4.06778366, 4.08954429,
#        4.15756327, 4.00234953, 4.119241  , 4.05481627, 4.06272837,
#        4.10549752, 4.08260669, 4.10091425, 4.12359717, 4.06393446,
#        4.07520158, 4.04822645, 4.10299184, 4.08947555, 4.10366381,
#        4.00521367, 4.12506472, 4.10145986, 4.05138119, 4.10429322,
#        4.07994094, 4.17808562, 4.06432673, 4.0099531 , 4.11697573,
#        4.01428166, 4.09208331, 4.10754842, 4.04284957, 4.10427701,
#        4.11309594, 4.07646845, 4.04815748, 4.07550755, 4.00314   ,
#        4.10085667, 4.09917338, 4.02114915, 3.99283741, 4.02262616,
#        4.05346626, 4.00200115, 4.10688839, 4.16970128, 4.02603049,
#        4.31301892, 4.08342315, 4.02236702, 4.08050471, 4.08691908,
#        4.05753271, 4.35060277, 4.39964509, 4.10465184, 4.2056321 ,
#        4.14248829, 4.04077175, 4.02717599, 4.19807135, 4.29597341,
#        4.21480495, 4.07518079, 4.00671792, 4.10585967, 4.07827345,
#        4.038318  , 4.10656037, 4.11868092, 4.05174757, 4.11291116,
#        4.13129634, 4.0628987 , 4.08941975, 4.07550755, 4.114177  ,
#        4.09207482, 4.11008117, 4.01114786, 4.10554576, 4.11088833,
#        4.0992832 , 4.02019173, 4.05174628, 4.02623991, 4.07451309,
#        4.06271288, 4.08156288, 4.10738854, 4.07045974, 4.10688218,
#        4.10674837, 4.11304041, 4.06541029, 4.10732271, 4.36365769,
#        4.10368348, 4.06505337, 4.08742417, 4.04405501, 4.11534716,
#        4.05301958, 4.12253667, 4.11814306, 4.3567879 , 4.59952674,
#        4.10654398, 4.07585503, 4.03152014, 4.05700388, 3.99976775,
#        4.0287223 , 4.10725324, 4.05929384, 4.32806865, 4.26305218,
#        4.05298186, 4.0804226 , 4.09536223, 4.06566734, 4.15544578,
#        4.05187307, 4.03696647, 4.03655165, 4.05077221, 4.05349172,
#        4.15492641, 4.09692633])

# %%
model.predict([[1000,300,24000,10]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([4.12230667])

# %%
y_predict=y_pred.tolist()
y_prediction=pd.DataFrame(y_predict)

# %%
y_prediction['rating']=df['rating']

# %%
y_prediction
# Out:
#             0  rating
# 0    4.112580     4.2
# 1    4.082621     4.0
# 2    4.163551     3.9
# 3    4.070293     4.2
# 4    4.032077     4.2
# ..        ...     ...
# 362  4.036552     4.4
# 363  4.050772     4.1
# 364  4.053492     4.2
# 365  4.154926     4.2
# 366  4.096926     4.1
#
# [367 rows x 2 columns]

# %%
plt.figure(figsize=(8, 6))
plt.hist(df['rating'], bins=5, edgecolor='k', alpha=0.7)
plt.title('Distribution of Ratings')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.show()

# %%
sns.pairplot(df)
